# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("Dataset.csv")
df.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
# Checking dataset structure
df.info()

# Checking column names
df.columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9551 entries, 0 to 9550
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has Table booking     9551 non-null   object
#  13  Has Online delivery   9551 non-null   object
#  14  Is delivering now     9551 non-null   object
# ...

# %%
# Count of different rating texts (e.g., Excellent, Good, Average)
plt.figure(figsize=(8,5))
sns.countplot(x='Rating text', data=df, palette="viridis", order=df['Rating text'].value_counts().index)
plt.title("Distribution of Review Categories")
plt.xlabel("Review Category")
plt.ylabel("Number of Restaurants")
plt.xticks(rotation=45)
plt.show()
print("This shows how many restaurants fall under Excellent / Good / Average / Poor categories.")
# Out:
# C:\Users\saich\AppData\Local\Temp\ipykernel_14792\433632565.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Rating text', data=df, palette="viridis", order=df['Rating text'].value_counts().index)
# This shows how many restaurants fall under Excellent / Good / Average / Poor categories.

# %%
# Average Aggregate Rating per Review Category
plt.figure(figsize=(8,5))
sns.barplot(x='Rating text', y='Aggregate rating', data=df, palette="coolwarm",
            order=df['Rating text'].value_counts().index)
plt.title("Average Rating per Review Category")
plt.xlabel("Review Category")
plt.ylabel("Average Aggregate Rating")
plt.xticks(rotation=45)
plt.show()
print("This shows the average rating for each review text (reviews linked to numerical ratings.")
# Out:
# C:\Users\saich\AppData\Local\Temp\ipykernel_14792\3832097014.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Rating text', y='Aggregate rating', data=df, palette="coolwarm",
# This shows the average rating for each review text (reviews linked to numerical ratings.

# %%
# Distribution of Votes
plt.figure(figsize=(8,5))
sns.histplot(df['Votes'], bins=40, kde=True, color='purple')
plt.title("Distribution of Votes")
plt.xlabel("Number of Votes")
plt.ylabel("Frequency")
plt.show()
print("This shows if votes are concentrated at low numbers or spread out.")
# Out:
# This shows if votes are concentrated at low numbers or spread out.

# %%
# Relationship between Votes and Ratings 
plt.figure(figsize=(10,6))
sns.regplot(x="Aggregate rating", y="Votes", data=df, scatter_kws={"alpha":0.5, "s":50}, 
            line_kws={"color":"red"}, color="green")
plt.title("Votes vs Aggregate Rating with Trend Line", fontsize=14, weight="bold")
plt.xlabel("Aggregate Rating", fontsize=12)
plt.ylabel("Number of Votes", fontsize=12)
plt.grid(True, alpha=0.3)
plt.show()
print("Helps us see if restaurants with higher ratings also receive more votes.")
# Out:
# Helps us see if restaurants with higher ratings also receive more votes.

# %%
# Top 10 most voted restaurants
top_votes = df[['Restaurant Name','Votes']].sort_values(by="Votes", ascending=False).head(10)

plt.figure(figsize=(10,6))
sns.barplot(x="Votes", y="Restaurant Name", data=top_votes, palette="mako")
plt.title("Top 10 Most Voted Restaurants")
plt.xlabel("Number of Votes")
plt.ylabel("Restaurant Name")
plt.show()
print("Shows the most popular restaurants based on votes")
# Out:
# C:\Users\saich\AppData\Local\Temp\ipykernel_14792\2715610449.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="Votes", y="Restaurant Name", data=top_votes, palette="mako")
# Shows the most popular restaurants based on votes

# %%
# !pip install wordcloud
# Out:
# ...
#   Using cached wordcloud-1.9.4-cp312-cp312-win_amd64.whl.metadata (3.5 kB)
# ...
# Using cached wordcloud-1.9.4-cp312-cp312-win_amd64.whl (301 kB)
# ...

# %%
from wordcloud import WordCloud, STOPWORDS

# Combine all review texts into one string
text = " ".join(str(review) for review in df['Rating text'].dropna())

# Generate word cloud
wordcloud = WordCloud(width=800, height=400, 
                      background_color="white", 
                      stopwords=STOPWORDS, 
                      colormap="viridis").generate(text)

# Plot the word cloud
plt.figure(figsize=(12,6))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.title("Word Cloud of Restaurant Review Texts")
plt.show()
print("The word cloud shows the most common review terms. Positive keywords (like 'Excellent' or 'Very Good') dominate, indicating overall customer satisfaction trends.")
# Out:
# The word cloud shows the most common review terms. Positive keywords (like 'Excellent' or 'Very Good') dominate, indicating overall customer satisfaction trends.

# %%
# Selecting numeric features
corr_features = df[['Aggregate rating', 'Votes', 'Price range']]

# Compute correlation
corr = corr_features.corr()

# Plot heatmap
plt.figure(figsize=(6,4))
sns.heatmap(corr, annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Correlation between Ratings, Votes, and Price Range")
plt.show()
print("The heatmap shows a positive correlation between ratings and votes, meaning highly rated restaurants get more customer engagement. Price range has a weaker correlation, suggesting affordability is not the only factor driving votes.")
# Out:
# The heatmap shows a positive correlation between ratings and votes, meaning highly rated restaurants get more customer engagement. Price range has a weaker correlation, suggesting affordability is not the only factor driving votes.

# %%
print("1. The majority of restaurants are rated as 'Good' or 'Average', indicating a generally satisfactory dining experience.")
print("2. Excellent-rated restaurants stand out with higher aggregate ratings, reflecting strong customer satisfaction.")
print("3. Vote distribution is skewed — most restaurants receive limited votes, while a few popular ones dominate with very high counts.")
print("4. A positive correlation exists between ratings and votes: higher-rated restaurants tend to attract more customer engagement.")
print("5. Overall, the dataset suggests that while many restaurants provide decent quality, only a select few achieve exceptional popularity and loyalty.")
# Out:
# 1. The majority of restaurants are rated as 'Good' or 'Average', indicating a generally satisfactory dining experience.
# 2. Excellent-rated restaurants stand out with higher aggregate ratings, reflecting strong customer satisfaction.
# 3. Vote distribution is skewed — most restaurants receive limited votes, while a few popular ones dominate with very high counts.
# 4. A positive correlation exists between ratings and votes: higher-rated restaurants tend to attract more customer engagement.
# 5. Overall, the dataset suggests that while many restaurants provide decent quality, only a select few achieve exceptional popularity and loyalty.
